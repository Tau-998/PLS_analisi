# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics


# importo i dati 
df_iscritti_tolc_23_24 = dict(pd.read_excel(r"C:\Users\lctal\Desktop\bonino\iscritti_23_24.xlsx"))

tot_immatricolati = len(df_iscritti_tolc_23_24['ID STUDENTE'])
print(tot_immatricolati) #stampa il numero di immatricolati per l'anno corrente
# Out:
# 241

# %%
# Dati per il diagramma a barre
years = ['18/19', '19/20', '20/21', '21/22', '22/23']
immatricolazioni = [264, 302, 264, 240, 241]  # Dati per le immatricolazioni
abbandoni = [91, 121, 98, 51, 72]  # Dati per gli abbandoni

# Larghezza delle barre
bar_width = 0.35

# Calcola la posizione delle barre per gli abbandoni
index = np.arange(len(years))

# Creazione del diagramma a barre
plt.bar(index, immatricolazioni, bar_width, color='blue', label='Immatricolazioni')
plt.bar(index + bar_width, abbandoni, bar_width, color='red', label='Abbandoni')

# Aggiungi i valori sopra le barre
for i in range(len(years)):
    plt.text(i, immatricolazioni[i] + 0.25, str(immatricolazioni[i]), ha='center', va='bottom')
    plt.text(i + bar_width, abbandoni[i] + 0.25, str(abbandoni[i]), ha='center', va='bottom')

# Aggiungi etichette e titolo
plt.xlabel('Anno Accademico')

plt.title('Immatricolazioni e abbandoni  2018-2023')
plt.xticks(index + bar_width / 2, years)  # Imposta le etichette sull'asse x
plt.legend()

# Mostra il diagramma
plt.show()


# Dati per il diagramma a barre
years = ['18/19', '19/20', '20/21', '21/22', '22/23']
percentages = [35, 40, 37, 23, 30]

# Creazione del diagramma a barre
plt.bar(years, percentages, color='yellow')

# Aggiungi etichette e titolo
plt.xlabel('Anno Accademico')
plt.ylabel('% Percentuale abbandoni')
plt.title('Percentuale abbandoni negli anni 2018-2023')

# Mostra il diagramma
plt.show()

# %%
years = ['11/12', '12/13', '13/14', '14/15', '15/16', '16/17', '17/18', '18/19', '19/20', '20/21', '21/22', '22/23']
percentages = [140, 147, 145, 160, 197, 247, 230, 245, 300, 266, 240, 241]

# Creazione del diagramma a barre
colors = ['tab:green'] * (len(years) - 1) + ['orange']  # Tutti verdi tranne l'ultima, che è arancione
plt.bar(years, percentages, color=colors)

# Aggiungi etichette e titolo
plt.xlabel('Anno Accademico')
plt.ylabel('# Immatricolazioni')
plt.title('Immatricolazioni 2011-2023')

# Riduci la dimensione delle etichette sull'asse x
plt.xticks(fontsize=8)

# Mostra il grafico
plt.show()

# %%
import pandas as pd

# Leggi il file Excel
df_iscritti_tolc_23_24 = pd.read_excel(r"C:\Users\lctal\Desktop\bonino\iscritti_23_24.xlsx")

# Filtra gli studenti per classe di voto
studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70)] 
studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80)]
studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90)]
studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100)]

# Accorpa i tipi di maturità
def accorpa_maturita(tipo_titolo_sup):
    if isinstance(tipo_titolo_sup, str):
        tipo_titolo_sup = tipo_titolo_sup.lower()
        if "tecnic" in tipo_titolo_sup or "perito" in tipo_titolo_sup or "professionale" in tipo_titolo_sup:
            return "Maturità tecnica"
        elif "scientific" in tipo_titolo_sup:
            if "tecnologica" in tipo_titolo_sup or "scienze applicate" in tipo_titolo_sup:
                return "Maturità scientifica tecnologica"
            else:
                return "Maturità scientifica"
        elif "classic" in tipo_titolo_sup:
            return "Maturità classica"
        else:
            return "Altro"
    else:
        return "Altro"

df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] = df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'].apply(accorpa_maturita)
#print(df_iscritti_tolc_23_24["TIPO_TITOLO_SUP"])



# Filtra per scuola di provenienza
# MATURITA' SCIENTIFICA
sc_studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica') ] 
sc_studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')]
sc_studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')]
sc_studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')]


# MATURITA' CLASSICA
cl_studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica') ] 
cl_studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')]
cl_studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')]
cl_studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')]

# MATURITA' TECNICA
tec_studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica') ] 
tec_studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')]
tec_studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')]
tec_studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')]

# MATURITA' SCIENZE APPLICATE
app_studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica') ] 
app_studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')]
app_studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')]
app_studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')]

# MATURITA' ALTRO
altro_studenti_classeA = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 60) & (df_iscritti_tolc_23_24['VOTO'] <= 70) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro') ] 
altro_studenti_classeB = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 71) & (df_iscritti_tolc_23_24['VOTO'] <= 80) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')]
altro_studenti_classeC = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 81) & (df_iscritti_tolc_23_24['VOTO'] <= 90) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')]
altro_studenti_classeD = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['VOTO'] >= 91) & (df_iscritti_tolc_23_24['VOTO'] <= 100) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')]



# Conta quanti studenti soddisfano il criterio
cont_A = studenti_classeA.shape[0]
cont_B = studenti_classeB.shape[0]
cont_C = studenti_classeC.shape[0]
cont_D = studenti_classeD.shape[0]
print("conteggi classe A [60-70]:", cont_A)
print("conteggi classe B [71-80]:", cont_B)
print("conteggi classe C [81-90]:", cont_C)
print("conteggi classe D [91-100]:", cont_D)

#-----------------------------------------------------------------------------------------------------------------------------------
print("--------------------------------------MATURITA' SCIENTIFICA------------------------------------------------------------------------")
sc_cont_A = sc_studenti_classeA.shape[0]
sc_cont_B = sc_studenti_classeB.shape[0]
sc_cont_C = sc_studenti_classeC.shape[0]
sc_cont_D = sc_studenti_classeD.shape[0]
print("Scientifica classe A [60-70]:", sc_cont_A)
print("Scientifica  classe B [71-80]:", sc_cont_B)
print("Scientifica classe C [81-90]:", sc_cont_C)
print("Scientifica  classe D [91-100]:", sc_cont_D)

#-----------------------------------------------------------------------------------------------------------------------------------
print("--------------------------------------MATURITA' CLASSICA------------------------------------------------------------------------")
cl_cont_A = cl_studenti_classeA.shape[0]
cl_cont_B = cl_studenti_classeB.shape[0]
cl_cont_C = cl_studenti_classeC.shape[0]
cl_cont_D = cl_studenti_classeD.shape[0]
print("Classica classe A [60-70]:", cl_cont_A)
print("Classica  classe B [71-80]:", cl_cont_B)
print("Classica classe C [81-90]:", cl_cont_C)
print("Classica  classe D [91-100]:", cl_cont_D)

#-----------------------------------------------------------------------------------------------------------------------------------
print("--------------------------------------MATURITA' TECNICA------------------------------------------------------------------------")
tec_cont_A = tec_studenti_classeA.shape[0]
tec_cont_B = tec_studenti_classeB.shape[0]
tec_cont_C = tec_studenti_classeC.shape[0]
tec_cont_D = tec_studenti_classeD.shape[0]
print("Tecnica classe A [60-70]:", tec_cont_A)
print("Tecnica  classe B [71-80]:", tec_cont_B)
print("Tecnica classe C [81-90]:", tec_cont_C)
print("Tecnica  classe D [91-100]:", tec_cont_D)

#-----------------------------------------------------------------------------------------------------------------------------------
print("--------------------------------------MATURITA' APPLICATE------------------------------------------------------------------------")
app_cont_A = app_studenti_classeA.shape[0]
app_cont_B = app_studenti_classeB.shape[0]
app_cont_C = app_studenti_classeC.shape[0]
app_cont_D = app_studenti_classeD.shape[0]
print("SC Applicate classe A [60-70]:", app_cont_A)
print("SC Appliicate classe B [71-80]:", app_cont_B)
print("SC Applicate C [81-90]:", app_cont_C)
print("SC Applicate  classe D [91-100]:", app_cont_D)

#-----------------------------------------------------------------------------------------------------------------------------------
print("--------------------------------------MATURITA' ALTRO------------------------------------------------------------------------")
altro_cont_A = altro_studenti_classeA.shape[0]
altro_cont_B = altro_studenti_classeB.shape[0]
altro_cont_C = altro_studenti_classeC.shape[0]
altro_cont_D = altro_studenti_classeD.shape[0]
print("Altro classe A [60-70]:", altro_cont_A)
print("Altro classe B [71-80]:", altro_cont_B)
print("Altro C [81-90]:", altro_cont_C)
print("Altro  classe D [91-100]:", altro_cont_D)



import matplotlib.pyplot as plt

# Lista delle classi di voto
classi_voto = ['A [60-70]', 'B [71-80]', 'C [81-90]', 'D [91-100]']

# Lista degli indirizzi di provenienza
indirizzi_provenienza = ['Scientifica', 'Classica', 'Tecnica', 'Scienze Applicate', 'Altro']

# Conteggi per ciascun indirizzo di provenienza
conteggi_indirizzi = [
    [sc_cont_A, sc_cont_B, sc_cont_C, sc_cont_D],
    [cl_cont_A, cl_cont_B, cl_cont_C, cl_cont_D],
    [tec_cont_A, tec_cont_B, tec_cont_C, tec_cont_D],
    [app_cont_A, app_cont_B, app_cont_C, app_cont_D],
    [altro_cont_A, altro_cont_B, altro_cont_C, altro_cont_D]
]

# Disegna l'istogramma
fig, ax = plt.subplots()
width = 0.15  # larghezza delle barre
x = range(len(classi_voto))  # posizioni sull'asse X per le barre

for i, (indirizzo, conteggi) in enumerate(zip(indirizzi_provenienza, conteggi_indirizzi)):
    ax.bar([pos + i * width for pos in x], conteggi, width=width, label=indirizzo)

ax.set_xlabel('Classi di Voto')
ax.set_ylabel('Conteggi')
ax.set_title('Distribuzione degli Studenti per Indirizzo di Provenienza e Classe di Voto')
ax.set_xticks([pos + 2 * width for pos in x])
ax.set_xticklabels(classi_voto)
ax.legend()

plt.show()
# Out:
# conteggi classe A [60-70]: 32
# conteggi classe B [71-80]: 46
# conteggi classe C [81-90]: 55
# conteggi classe D [91-100]: 106
# --------------------------------------MATURITA' SCIENTIFICA------------------------------------------------------------------------
# Scientifica classe A [60-70]: 6
# Scientifica  classe B [71-80]: 18
# Scientifica classe C [81-90]: 26
# Scientifica  classe D [91-100]: 42
# --------------------------------------MATURITA' CLASSICA------------------------------------------------------------------------
# Classica classe A [60-70]: 3
# Classica  classe B [71-80]: 3
# Classica classe C [81-90]: 8
# Classica  classe D [91-100]: 13
# --------------------------------------MATURITA' TECNICA------------------------------------------------------------------------
# Tecnica classe A [60-70]: 8
# Tecnica  classe B [71-80]: 7
# Tecnica classe C [81-90]: 4
# Tecnica  classe D [91-100]: 13
# ...

# %%
# ----------------------------------------------------------------- TEST DI VALUTAZIONE IMMATRICOLAZIONE ------------------------------------------------- #


#----------------------------- OFA MATEMATICA DI BASE -----------------------------------------------------------------------------------------------------#

# Filtra per scuola di provenienza
# MATURITA' SCIENTIFICA
df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].str.replace(',', '.')
df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].astype(float)


M_OFA_sc_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')] 
M_OFA_cl_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')] 
M_OFA_tec_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')] 
M_OFA_app_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')] 
M_OFA_altro_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')] 

cont_sc_OFA_M = M_OFA_sc_studenti.shape[0]
cont_cl_OFA_M = M_OFA_cl_studenti.shape[0]
cont_tec_OFA_M = M_OFA_tec_studenti.shape[0]
cont_app_OFA_M = M_OFA_app_studenti.shape[0]
cont_altro_OFA_M = M_OFA_altro_studenti.shape[0]

print("OFA MATEMATICA DI BASE maturità scientifica", cont_sc_OFA_M)
print("OFA MATEMATICA DI BASE maturità classica", cont_cl_OFA_M)
print("OFA MATEMATICA DI BASE maturità tecnica", cont_tec_OFA_M)
print("OFA MATEMATICA DI BASE maturità scientifica tecnologica", cont_app_OFA_M)
print("OFA MATEMATICA DI BASE maturità altro", cont_altro_OFA_M)

sc_studenti = df_iscritti_tolc_23_24[ (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')] 
cl_studenti = df_iscritti_tolc_23_24[ (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')] 
tec_studenti = df_iscritti_tolc_23_24[ (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')] 
app_studenti = df_iscritti_tolc_23_24[ (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')] 
altro_studenti = df_iscritti_tolc_23_24[ (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')] 

cont_sc = sc_studenti.shape[0]
cont_cl = cl_studenti.shape[0]
cont_tec = tec_studenti.shape[0]
cont_app = app_studenti.shape[0]
cont_altro = altro_studenti.shape[0]

print(" maturità scientifica", cont_sc)
print(" maturità classica", cont_cl)
print(" maturità tecnica", cont_tec)
print(" maturità scientifica tecnologica", cont_app)
print(" maturità altro", cont_altro)



import matplotlib.pyplot as plt

# Numero totale di studenti senza OFA per ciascun tipo di maturità
num_no_OFA = [cont_sc - cont_sc_OFA_M, cont_cl - cont_cl_OFA_M, cont_tec - cont_tec_OFA_M, cont_app - cont_app_OFA_M, cont_altro - cont_altro_OFA_M]

# Numero totale di studenti con OFA per ciascun tipo di maturità
num_OFA = [cont_sc_OFA_M, cont_cl_OFA_M, cont_tec_OFA_M, cont_app_OFA_M, cont_altro_OFA_M]

# Etichette per i tipi di maturità
labels = [' scientifica', ' classica', ' tecnica', ' tecnologica', 'Altro']

# Posizioni delle barre
x = range(len(labels))

# Larghezza delle barre
width = 0.4

# Disegna il grafico
fig, ax = plt.subplots()
bar1 = ax.bar(x, num_no_OFA, width, color='b', label='Senza OFA')
bar2 = ax.bar([i + width for i in x], num_OFA, width, color='r', label='Con OFA')

# Aggiungi etichette, titoli e legenda
ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(labels, ha='center')  # Imposta l'orientamento a 'horizontal'
ax.set_ylabel('Numero di studenti')
ax.set_title('Provenienza degli studenti con e senza OFA in Matematica di Base')
ax.legend()

# Funzione per aggiungere etichette sopra le barre
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.0f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

# Aggiungi etichette sopra le barre
add_labels(bar1)
add_labels(bar2)

# Mostra il grafico
plt.tight_layout()
plt.show()

print("--------------------------------------------------------------------------------------------------------------------------------")
import matplotlib.pyplot as plt

# Dati dei conteggi degli OFA per ogni tipologia di maturità
tipi_maturita = ['Scientifica', 'Classica', 'Tecnica', ' Tecnologica', 'Altro']
conteggi_OFA = [3, 2, 5, 2, 6]

# Dati dei conteggi delle varie tipologie di maturità
conteggi_maturita = [93, 27, 33, 64, 24]

# Creazione dell'istogramma
plt.bar(tipi_maturita, conteggi_maturita, color='blue', label='Maturità')
plt.bar(tipi_maturita, conteggi_OFA, color='red', label='OFA')

# Aggiunta delle etichette e del titolo
plt.xlabel('Tipologia di Maturità')
plt.ylabel('Conteggio')
plt.title('Conteggio OFA Matematica')
plt.legend()

# Mostra il grafico
plt.show()
# Out:
# OFA MATEMATICA DI BASE maturità scientifica 3
# OFA MATEMATICA DI BASE maturità classica 2
# OFA MATEMATICA DI BASE maturità tecnica 5
# OFA MATEMATICA DI BASE maturità scientifica tecnologica 2
# OFA MATEMATICA DI BASE maturità altro 6
#  maturità scientifica 93
#  maturità classica 27
#  maturità tecnica 33
#  maturità scientifica tecnologica 64
#  maturità altro 24
# --------------------------------------------------------------------------------------------------------------------------------

# %%
df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] = df_iscritti_tolc_23_24['SCIENZE_DI_BASE'].str.replace(',', '.')
df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] = df_iscritti_tolc_23_24['SCIENZE_DI_BASE'].astype(float)


sdb_OFA_sc_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica')] 
sdb_OFA_cl_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità classica')] 
sdb_OFA_tec_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità tecnica')] 
sdb_OFA_app_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Maturità scientifica tecnologica')] 
sdb_OFA_altro_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['TIPO_TITOLO_SUP'] == 'Altro')] 

cont_sc_OFA_sdb = sdb_OFA_sc_studenti.shape[0]
cont_cl_OFA_sdb = sdb_OFA_cl_studenti.shape[0]
cont_tec_OFA_sdb = sdb_OFA_tec_studenti.shape[0]
cont_app_OFA_sdb = sdb_OFA_app_studenti.shape[0]
cont_altro_OFA_sdb = sdb_OFA_altro_studenti.shape[0]

print("OFA SCIENZE DI BASE maturità scientifica", cont_sc_OFA_sdb)
print("OFA SCIENZE DI BASE maturità classica", cont_cl_OFA_sdb)
print("OFA SCIENZE DI BASE maturità tecnica", cont_tec_OFA_sdb)
print("OFA SCIENZE DI BASE maturità scientifica tecnologica", cont_app_OFA_sdb)
print("OFA SCIENZE DI BASE maturità altro", cont_altro_OFA_sdb)


import matplotlib.pyplot as plt

# Dati dei conteggi degli OFA per ogni tipologia di maturità
tipi_maturita = ['Scientifica', 'Classica', 'Tecnica', ' Tecnologica', 'Altro']
conteggi_OFA = [8, 3, 7, 6, 5]

# Dati dei conteggi delle varie tipologie di maturità
conteggi_maturita = [93, 27, 33, 64, 24]

# Creazione dell'istogramma
plt.bar(tipi_maturita, conteggi_maturita, color='blue', label='Maturità')
plt.bar(tipi_maturita, conteggi_OFA, color='gold', label='OFA')

# Aggiunta delle etichette e del titolo
plt.xlabel('Tipologia di Maturità')
plt.ylabel('Conteggio')
plt.title('Conteggio OFA Scienze di base')
plt.legend()

# Mostra il grafico
plt.show()
# Out:
# OFA SCIENZE DI BASE maturità scientifica 8
# OFA SCIENZE DI BASE maturità classica 3
# OFA SCIENZE DI BASE maturità tecnica 7
# OFA SCIENZE DI BASE maturità scientifica tecnologica 6
# OFA SCIENZE DI BASE maturità altro 5

# %%
tot_sdb_OFA_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) ] 
tot_m_OFA_studenti = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5) ] 
tot_m_sdb_OFA =df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] < 2.5) & (df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] < 5)]

cont_tot_OFA_sdb = tot_sdb_OFA_studenti.shape[0]
cont_tot_OFA_m = tot_m_OFA_studenti.shape[0]

print("Totale stundent3 OFA Matematica", cont_tot_OFA_m)
print("Totale stundent3 OFA Scienze di base ", cont_tot_OFA_sdb)
print("Totale stundent3 OFA Scienze di base + Matematica ", len(tot_m_sdb_OFA))



import matplotlib.pyplot as plt

# Dati
provenienze = ['Scientifica', 'Classica', 'Tecnica', 'Scientifica Tecnologica', 'Altro']
conteggi_OFA = [8, 3, 7, 6, 5]

# Generazione del grafico a torta
plt.figure(figsize=(8, 6))
plt.pie(conteggi_OFA, labels=provenienze, autopct='%1.1f%%', startangle=140)

# Personalizzazione del grafico
plt.title('Percentuale delle provenienze degli studenti con OFA nelle Scienze di Base')

# Mostra il grafico
plt.show()

import matplotlib.pyplot as plt

# Dati
provenienze = ['Scientifica', 'Classica', 'Tecnica', 'Scientifica Tecnologica', 'Altro']
conteggi_OFA = [3, 2, 5, 2, 6]

# Generazione del grafico a torta
plt.figure(figsize=(8, 6))
plt.pie(conteggi_OFA, labels=provenienze, autopct='%1.1f%%', startangle=140)

# Personalizzazione del grafico
plt.title('Percentuale delle provenienze degli studenti con OFA nella Matematica di Base')

# Mostra il grafico
plt.show()
# Out:
# Totale stundent3 OFA Matematica 18
# Totale stundent3 OFA Scienze di base  29
# Totale stundent3 OFA Scienze di base + Matematica  4

# %%
#---- cerco distribuzione dei punteggi per i vari test --------#
# mate max 20 ---- scienze max 10 ---- ragionamento max 10 ------ TARM max 80
# Suddivisione della popolazione studentesca in classi di voto A B C D E --------> 5 CLASSI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 7
#       1 #---- cerco distribuzione dei punteggi per i vari test --------#
#       2 # mate max 20 ---- scienze max 10 ---- ragionamento max 10 ------ TARM max 80
#       3 # Suddivisione della popolazione studentesca in classi di voto A B C D E --------> 5 CLASSI
#       4 #------------------------------------------------------ MATEMATICA ----------------------------------------------------------------------#
# ----> 7 df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].str.replace(',', '.').astype(float)
#       8 df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].astype(float)
#       9 # Calcola la percentuale del voto in base a un massimo di 10 punti
#
# ...

# %%
print("----------------------------------SCIENZE DI BASE: conteggio per classi ----------------------------------------------------")
#---------------------------------------------------- SCIENZE DI BASE ----------------------------------------------#


#df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] = df_iscritti_tolc_23_24['SCIENZE_DI_BASE'].str.replace(',', '.').astype(float)
df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] = df_iscritti_tolc_23_24['SCIENZE_DI_BASE'].astype(float)
# Calcola la percentuale del voto in base a un massimo di 10 punti
df_iscritti_tolc_23_24['Percentuale_voto'] = (df_iscritti_tolc_23_24['SCIENZE_DI_BASE'] / 10) * 100

# Crea le sezioni
A_scienze = df_iscritti_tolc_23_24[df_iscritti_tolc_23_24['Percentuale_voto'] < 25]
B_scienze = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 25) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 50)]
C_scienze = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 50) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 75)]
D_scienze = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 75) & (df_iscritti_tolc_23_24['Percentuale_voto'] <= 100)]


# Stampa il numero di studenti in ciascuna sezione
print("Numero di studenti nella sezione A_scienze:", len(A_scienze))
print("Numero di studenti nella sezione B_scienze:", len(B_scienze))
print("Numero di studenti nella sezione C_scienze:", len(C_scienze))
print("Numero di studenti nella sezione D_scienze:", len(D_scienze))
# Out:
# ----------------------------------SCIENZE DI BASE: conteggio per classi ----------------------------------------------------
# Numero di studenti nella sezione A_scienze: 29
# Numero di studenti nella sezione B_scienze: 59
# Numero di studenti nella sezione C_scienze: 72
# Numero di studenti nella sezione D_scienze: 59

# %%
#---------------------------------------------------- RAGIONAMENTO E PROBLEMI  ----------------------------------------------#
print("-------------------------------------- RAGIONAMENTO E PROBLEMI: conteggio per classi  ----------------------------------------------------------------")


#df_iscritti_tolc_23_24['Ragionamento e problemi'] = df_iscritti_tolc_23_24['Ragionamento e problemi'].str.replace(',', '.').astype(float)
df_iscritti_tolc_23_24['Ragionamento e problemi'] = df_iscritti_tolc_23_24['Ragionamento e problemi'].astype(float)
# Calcola la percentuale del voto in base a un massimo di 10 punti
df_iscritti_tolc_23_24['Percentuale_voto'] = (df_iscritti_tolc_23_24['Ragionamento e problemi'] / 10) * 100

# Crea le sezioni
A_r = df_iscritti_tolc_23_24[df_iscritti_tolc_23_24['Percentuale_voto'] < 25]
B_r = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 25) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 50)]
C_r = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 50) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 75)]
D_r = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 75) & (df_iscritti_tolc_23_24['Percentuale_voto'] <= 100)]


# Stampa il numero di studenti in ciascuna sezione
print("Numero di studenti nella sezione A_ragionamento:", len(A_r))
print("Numero di studenti nella sezione B_ragionamento:", len(B_r))
print("Numero di studenti nella sezione C_ragionamento:", len(C_r))
print("Numero di studenti nella sezione D_ragionamento:", len(D_r))
# Out:
# -------------------------------------- RAGIONAMENTO E PROBLEMI: conteggio per classi  ----------------------------------------------------------------
# Numero di studenti nella sezione A_ragionamento: 44
# Numero di studenti nella sezione B_ragionamento: 87
# Numero di studenti nella sezione C_ragionamento: 60
# Numero di studenti nella sezione D_ragionamento: 28

# %%
print("----------------------------------MATEMATICA DI BASE: conteggio per classi ----------------------------------------------------")
#------------------------------------------------------ MATEMATICA ----------------------------------------------------------------------
#df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].str.replace(',', '.').astype(float)
df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] = df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'].astype(float)
# Calcola la percentuale del voto in base a un massimo di 10 punti
df_iscritti_tolc_23_24['Percentuale_voto'] = (df_iscritti_tolc_23_24['MATEMATICA_DI_BASE'] / 20) * 100

# Crea le sezioni
A_mate = df_iscritti_tolc_23_24[df_iscritti_tolc_23_24['Percentuale_voto'] < 25]
B_mate = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 25) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 50)]
C_mate = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 50) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 75)]
D_mate = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 75) & (df_iscritti_tolc_23_24['Percentuale_voto'] <= 100)]
vuoti = df_iscritti_tolc_23_24[pd.isna(df_iscritti_tolc_23_24['Percentuale_voto'])]


# Stampa il numero di studenti in ciascuna sezione
print("Numero di studenti nella sezione A_mate:", len(A_mate))
print("Numero di studenti nella sezione B_mate:", len(B_mate))
print("Numero di studenti nella sezione C_mate:", len(C_mate))
print("Numero di studenti nella sezione D_mate:", len(D_mate))
print("Celle vuote nella colonna",len(vuoti))
# Out:
# ----------------------------------MATEMATICA DI BASE: conteggio per classi ----------------------------------------------------
# Numero di studenti nella sezione A_mate: 18
# Numero di studenti nella sezione B_mate: 64
# Numero di studenti nella sezione C_mate: 42
# Numero di studenti nella sezione D_mate: 95
# Celle vuote nella colonna 22
# 241

# %%
#---------------------------------------------------- TARM  ----------------------------------------------#
print("-------------------------------------- TARM: conteggio per classi  ----------------------------------------------------------------")

#df_iscritti_tolc_23_24['TEST_ACCERTAMENTO'] = df_iscritti_tolc_23_24['TEST_ACCERTAMENTO'].str.replace(',', '.').astype(float)
df_iscritti_tolc_23_24['TEST_ACCERTAMENTO'] = df_iscritti_tolc_23_24['TEST_ACCERTAMENTO'].astype(float)
# Calcola la percentuale del voto in base a un massimo di 10 punti
df_iscritti_tolc_23_24['Percentuale_voto'] = (df_iscritti_tolc_23_24['TEST_ACCERTAMENTO'] / 80) * 100

# Crea le sezioni
A_tarm = df_iscritti_tolc_23_24[df_iscritti_tolc_23_24['Percentuale_voto'] < 25]
B_tarm = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 25) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 50)]
C_tarm = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 50) & (df_iscritti_tolc_23_24['Percentuale_voto'] < 75)]
D_tarm = df_iscritti_tolc_23_24[(df_iscritti_tolc_23_24['Percentuale_voto'] >= 75) & (df_iscritti_tolc_23_24['Percentuale_voto'] <= 100)]


# Stampa il numero di studenti in ciascuna sezione
print("Numero di studenti nella sezione A_tarm:", len(A_tarm))
print("Numero di studenti nella sezione B_tarm:", len(B_tarm))
print("Numero di studenti nella sezione C_tarm:", len(C_tarm))
print("Numero di studenti nella sezione D_tarm:", len(D_tarm))
# Out:
# -------------------------------------- TARM: conteggio per classi  ----------------------------------------------------------------
# Numero di studenti nella sezione A_tarm: 4
# Numero di studenti nella sezione B_tarm: 38
# Numero di studenti nella sezione C_tarm: 98
# Numero di studenti nella sezione D_tarm: 79

# %%
import matplotlib.pyplot as plt

# Definizione dei dati
classi_voto = ['A', 'B', 'C', 'D']  # Classi di voto simili alle tue sezioni
sezioni = ['Matematica di base', 'Scienze di base', 'Ragionamento e problemi', 'Tarm']
num_studenti = [
    [],  # Dati per le sezioni "Mate"
    [],  # Dati per le sezioni "Scienze"
    [],  # Dati per le sezioni "Ragionamento"
    []    # Dati per le sezioni "Tarm"
]

# Definizione dei colori per le sezioni
colori = ['tab:blue', 'gold', 'red', 'green']  # Colore corrispondente per le sezioni Mate, Scienze, Ragionamento, Tarm

# Disegna l'istogramma
fig, ax = plt.subplots()
width = 0.15  # larghezza delle barre
x = range(len(classi_voto))  # posizioni sull'asse X per le barre

for i, (sezione, conteggi) in enumerate(zip(sezioni, num_studenti)):
    ax.bar([pos + i * width for pos in x], conteggi, width=width, label=sezione, color=colori[i])

ax.set_xlabel('Classi di Voto')
ax.set_ylabel('Numero di Studenti')
ax.set_title('Distribuzione degli Studenti per sezione e classe di voto')
ax.set_xticks([pos + 2 * width for pos in x])
ax.set_xticklabels(classi_voto)
ax.legend()

plt.show()
